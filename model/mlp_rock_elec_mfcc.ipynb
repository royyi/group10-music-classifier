# %%
import pandas as pd
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler

elec = pd.read_csv('..\dataset generation\small_elec_features.csv')
elec['Class'] = 'elec'
elec = elec.iloc[2:, 1:]
#print(elec.head())
#print(elec.shape)

rock = pd.read_csv('..\dataset generation\small_rock_features.csv')
rock['Class'] = 'rock'
rock = rock.iloc[2:, 1:]
#print(rock.head())
#print(rock.shape)

df = pd.concat([elec, rock])
df = df.sample(frac=1).reset_index(drop=True)
#print(df.head())
#print(df.shape)

col = df.columns.get_loc('mfcc')
mfcc = df.iloc[:, col:col+140]
clas = df['Class']
df = pd.concat([mfcc, clas], axis=1)

y_data = df['Class']
x_data = df.drop('Class', axis = 1)

class_data = pd.get_dummies(df['Class'], drop_first = False)

scaler = MinMaxScaler()
scaled = scaler.fit_transform(x_data)
x_df = DataFrame(scaled)

df = pd.concat([x_df, class_data], axis = 1)
df = df.dropna()
print(df.head())
print(df.shape)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.003726  0.006590  0.112600  0.064279  0.181075  0.144366  0.137185
# 1  0.023029  0.022019  0.182357  0.082678  0.111561  0.103441  0.108151
# 2  0.008742  0.005628  0.559984  0.058026  0.251543  0.150085  0.182118
# 3  0.002963  0.008525  0.095692  0.062252  0.125961  0.096252  0.107540
# 4  0.027465  0.015992  0.155092  0.052292  0.117690  0.073475  0.146549
#
#           7         8         9  ...       132       133       134       135  \
# 0  0.108869  0.325683  0.226048  ...  0.192042  0.201825  0.162472  0.140605
# 1  0.090657  0.176594  0.109216  ...  0.086641  0.075689  0.082185  0.050522
# 2  0.094231  0.139303  0.131240  ...  0.110658  0.130908  0.124006  0.108014
# 3  0.109592  0.130127  0.115679  ...  0.307643  0.525281  0.449779  0.385350
# 4  0.081661  0.147089  0.143395  ...  0.115965  0.197621  0.152140  0.126997
#
#         136       137       138       139  elec  rock
# 0  0.166513  0.150995  0.219999  0.175184     1     0
# 1  0.082520  0.090318  0.128794  0.156342     0     1
# 2  0.119295  0.083485  0.093184  0.183625     0     1
# 3  0.348069  0.326056  0.301312  0.262471     1     0
# 4  0.121913  0.101419  0.136894  0.112937     0     1
#
# [5 rows x 142 columns]
# (1998, 142)

# %%
from sklearn.model_selection import train_test_split

y_cols = ['rock', 'elec']
y_data = df[y_cols]
x_data = df.drop(y_data, axis = 1)

x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x_data, y_data, test_size = 0.1)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(solver = 'sgd', random_state = 42, activation = 'logistic', learning_rate_init = 0.3, batch_size = 300, hidden_layer_sizes = (70,40), max_iter = 500)
mlp.fit(x_training_data, y_training_data)
predictions = mlp.predict(x_test_data)

print("Confusion Matrix:")
print(multilabel_confusion_matrix(y_test_data, predictions))
print("\nAccuracy:", accuracy_score(y_test_data, predictions))
print("\nMSE:", mean_squared_error(y_test_data, predictions))
print("\nClassification Report:")
print(classification_report(y_test_data, predictions))
# Out:
# Confusion Matrix:
# [[[95  7]
#   [23 75]]
#
#  [[76 22]
#   [ 7 95]]]
#
# Accuracy: 0.85
#
# MSE: 0.1475
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        98
#            1       0.81      0.93      0.87       102
#
#    micro avg       0.85      0.85      0.85       200
#    macro avg       0.86      0.85      0.85       200
# weighted avg       0.86      0.85      0.85       200
#  samples avg       0.85      0.85      0.85       200
# c:\Users\micha\anaconda3\envs\env1\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import GridSearchCV, KFold

learning_rate_init = [0.2, 0.3, 0.4]
max_iter = [300, 500, 700]
hidden_layer_sizes = [(70,40), (32,8), (12,3)]
solver = ['sgd']
random_state = [42]
activation = ['logistic']
batch_size = [300]


# Make a dictionary of the grid search parameters
param_grid = dict(learning_rate_init=learning_rate_init, max_iter=max_iter, hidden_layer_sizes=hidden_layer_sizes, solver=solver, random_state=random_state, activation=activation, batch_size=batch_size)

# Build and fit the GridSearchCV
grid = GridSearchCV(estimator=mlp, param_grid=param_grid,
                    cv=KFold(), verbose=10)

grid_results = grid.fit(x_data, y_data)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5; 1/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 1/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.823 total time=   0.2s
# [CV 2/5; 1/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 1/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.882 total time=   0.5s
# [CV 3/5; 1/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 1/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.830 total time=   0.6s
# [CV 4/5; 1/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 1/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.820 total time=   0.2s
# [CV 5/5; 1/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 1/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.882 total time=   0.2s
# [CV 1/5; 2/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 2/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.823 total time=   0.2s
# [CV 2/5; 2/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 2/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.882 total time=   0.5s
# [CV 3/5; 2/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 2/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.830 total time=   0.5s
# [CV 4/5; 2/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 2/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.820 total time=   0.2s
# [CV 5/5; 2/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 2/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.882 total time=   0.2s
# [CV 1/5; 3/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 3/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.823 total time=   0.2s
# [CV 2/5; 3/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 3/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.882 total time=   0.5s
# [CV 3/5; 3/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 3/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.830 total time=   0.5s
# [CV 4/5; 3/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 3/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.820 total time=   0.2s
# [CV 5/5; 3/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 3/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.882 total time=   0.3s
# [CV 1/5; 4/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 4/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.830 total time=   0.2s
# [CV 2/5; 4/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 4/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.855 total time=   0.5s
# [CV 3/5; 4/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 4/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.840 total time=   0.9s
# [CV 4/5; 4/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 4/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.832 total time=   0.5s
# [CV 5/5; 4/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 4/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.882 total time=   0.3s
# [CV 1/5; 5/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 5/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.830 total time=   0.2s
# [CV 2/5; 5/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 5/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.855 total time=   0.6s
# [CV 3/5; 5/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 5/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.840 total time=   1.1s
# [CV 4/5; 5/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 5/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.832 total time=   0.6s
# [CV 5/5; 5/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 5/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.882 total time=   0.3s
# [CV 1/5; 6/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 6/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 2/5; 6/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 6/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.855 total time=   0.6s
# [CV 3/5; 6/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 6/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.840 total time=   1.0s
# [CV 4/5; 6/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 6/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.832 total time=   0.5s
# [CV 5/5; 6/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 6/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.882 total time=   0.3s
# [CV 1/5; 7/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 7/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.850 total time=   0.4s
# [CV 2/5; 7/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 7/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.887 total time=   0.5s
# [CV 3/5; 7/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 7/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.800 total time=   1.0s
# [CV 4/5; 7/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 7/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.865 total time=   0.6s
# [CV 5/5; 7/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 7/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 1/5; 8/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 8/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.850 total time=   0.3s
# [CV 2/5; 8/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 8/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.887 total time=   0.5s
# [CV 3/5; 8/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 8/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.800 total time=   1.0s
# [CV 4/5; 8/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 8/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.865 total time=   0.6s
# [CV 5/5; 8/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 8/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.885 total time=   0.3s
# [CV 1/5; 9/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 9/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.850 total time=   0.3s
# [CV 2/5; 9/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 9/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.887 total time=   0.5s
# [CV 3/5; 9/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 9/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.800 total time=   1.0s
# [CV 4/5; 9/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 9/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.865 total time=   0.6s
# [CV 5/5; 9/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 9/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(70, 40), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 1/5; 10/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 10/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.855 total time=   0.5s
# [CV 2/5; 10/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 10/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.882 total time=   0.5s
# [CV 3/5; 10/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 10/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 4/5; 10/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 10/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.860 total time=   0.5s
# [CV 5/5; 10/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 10/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.865 total time=   0.3s
# [CV 1/5; 11/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 11/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.855 total time=   0.4s
# [CV 2/5; 11/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 11/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.882 total time=   0.4s
# [CV 3/5; 11/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 11/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.830 total time=   0.4s
# [CV 4/5; 11/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 11/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.860 total time=   0.6s
# [CV 5/5; 11/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 11/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.865 total time=   0.5s
# [CV 1/5; 12/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 12/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.855 total time=   0.7s
# [CV 2/5; 12/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 12/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.882 total time=   0.6s
# [CV 3/5; 12/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 12/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 4/5; 12/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 12/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.860 total time=   0.6s
# [CV 5/5; 12/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 12/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.865 total time=   0.4s
# [CV 1/5; 13/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 13/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.855 total time=   0.3s
# [CV 2/5; 13/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 13/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.892 total time=   0.6s
# [CV 3/5; 13/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 13/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.835 total time=   0.5s
# [CV 4/5; 13/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 13/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.850 total time=   0.3s
# [CV 5/5; 13/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 13/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.880 total time=   0.2s
# [CV 1/5; 14/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 14/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.855 total time=   0.4s
# [CV 2/5; 14/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 14/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.892 total time=   0.6s
# [CV 3/5; 14/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 14/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.835 total time=   0.5s
# [CV 4/5; 14/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 14/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.850 total time=   0.3s
# [CV 5/5; 14/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 14/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.880 total time=   0.2s
# [CV 1/5; 15/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 15/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.855 total time=   0.3s
# [CV 2/5; 15/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 15/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.892 total time=   0.5s
# [CV 3/5; 15/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 15/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.835 total time=   0.4s
# [CV 4/5; 15/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 15/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.850 total time=   0.3s
# [CV 5/5; 15/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 15/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.880 total time=   0.2s
# [CV 1/5; 16/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 16/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.775 total time=   0.6s
# [CV 2/5; 16/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 16/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 3/5; 16/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 16/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 4/5; 16/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 16/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 16/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 16/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 1/5; 17/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 17/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.775 total time=   0.6s
# [CV 2/5; 17/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 17/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 3/5; 17/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 17/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 4/5; 17/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 17/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 17/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 17/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 1/5; 18/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 18/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.775 total time=   0.6s
# [CV 2/5; 18/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 18/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 3/5; 18/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 18/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.830 total time=   0.3s
# [CV 4/5; 18/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 18/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 18/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 18/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(32, 8), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 1/5; 19/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 19/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.848 total time=   0.1s
# [CV 2/5; 19/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 19/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.777 total time=   0.3s
# [CV 3/5; 19/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 19/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 19/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 19/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.862 total time=   0.2s
# [CV 5/5; 19/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 19/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=300, random_state=42, solver=sgd;, score=0.840 total time=   0.4s
# [CV 1/5; 20/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 20/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.848 total time=   0.1s
# [CV 2/5; 20/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 20/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.777 total time=   0.3s
# [CV 3/5; 20/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 20/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 20/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 20/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.862 total time=   0.2s
# [CV 5/5; 20/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 20/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=500, random_state=42, solver=sgd;, score=0.840 total time=   0.4s
# [CV 1/5; 21/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 21/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.848 total time=   0.1s
# [CV 2/5; 21/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 21/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.777 total time=   0.4s
# [CV 3/5; 21/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 21/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 21/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 21/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.862 total time=   0.2s
# [CV 5/5; 21/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 21/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.2, max_iter=700, random_state=42, solver=sgd;, score=0.840 total time=   0.4s
# [CV 1/5; 22/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 22/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 2/5; 22/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 22/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.885 total time=   0.1s
# [CV 3/5; 22/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 22/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 22/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 22/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 22/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 22/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=300, random_state=42, solver=sgd;, score=0.897 total time=   0.2s
# [CV 1/5; 23/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 23/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.858 total time=   0.2s
# [CV 2/5; 23/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 23/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.885 total time=   0.1s
# [CV 3/5; 23/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 23/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 23/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 23/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 23/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 23/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=500, random_state=42, solver=sgd;, score=0.897 total time=   0.2s
# [CV 1/5; 24/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 24/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.858 total time=   0.2s
# [CV 2/5; 24/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 24/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.885 total time=   0.2s
# [CV 3/5; 24/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 24/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.858 total time=   0.1s
# [CV 4/5; 24/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 24/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.857 total time=   0.2s
# [CV 5/5; 24/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 24/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.3, max_iter=700, random_state=42, solver=sgd;, score=0.897 total time=   0.2s
# [CV 1/5; 25/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 1/5; 25/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.855 total time=   0.1s
# [CV 2/5; 25/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 2/5; 25/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.890 total time=   0.1s
# [CV 3/5; 25/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 3/5; 25/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.748 total time=   0.0s
# [CV 4/5; 25/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 4/5; 25/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.772 total time=   0.1s
# [CV 5/5; 25/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd
# [CV 5/5; 25/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=300, random_state=42, solver=sgd;, score=0.882 total time=   0.1s
# [CV 1/5; 26/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 1/5; 26/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.855 total time=   0.1s
# [CV 2/5; 26/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 2/5; 26/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.890 total time=   0.1s
# [CV 3/5; 26/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 3/5; 26/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.748 total time=   0.0s
# [CV 4/5; 26/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 4/5; 26/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.772 total time=   0.1s
# [CV 5/5; 26/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd
# [CV 5/5; 26/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=500, random_state=42, solver=sgd;, score=0.882 total time=   0.1s
# [CV 1/5; 27/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 1/5; 27/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.855 total time=   0.2s
# [CV 2/5; 27/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 2/5; 27/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.890 total time=   0.1s
# [CV 3/5; 27/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 3/5; 27/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.748 total time=   0.1s
# [CV 4/5; 27/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 4/5; 27/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.772 total time=   0.1s
# [CV 5/5; 27/27] START activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd
# [CV 5/5; 27/27] END activation=logistic, batch_size=300, hidden_layer_sizes=(12, 3), learning_rate_init=0.4, max_iter=700, random_state=42, solver=sgd;, score=0.882 total time=   0.1s

# %%
print("Optimal Paramaters:", grid_results.best_params_)
print("\nOptimal Hidden Layer Sizes:", grid_results.best_params_['hidden_layer_sizes'])
print("\nOptimal Learning Rate:", grid_results.best_params_['learning_rate_init'])
print("\nOptimal Number of Epochs:", grid_results.best_params_['max_iter'])
print("\nMax Accuracy:", grid_results.best_score_)
# Out:
# Optimal Paramaters: {'activation': 'logistic', 'batch_size': 300, 'hidden_layer_sizes': (32, 8), 'learning_rate_init': 0.3, 'max_iter': 300, 'random_state': 42, 'solver': 'sgd'}
#
# Optimal Hidden Layer Sizes: (32, 8)
#
# Optimal Learning Rate: 0.3
#
# Optimal Number of Epochs: 300
#
# Max Accuracy: 0.8623646616541354
